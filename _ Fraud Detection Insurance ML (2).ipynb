# %% [markdown]
# dataset link:https://www.kaggle.com/datasets/shivamb/vehicle-claim-fraud-detection

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("fraud_oracle.csv")
df.head()
# Out:
#   Month  WeekOfMonth  DayOfWeek    Make AccidentArea DayOfWeekClaimed  \
# 0   Dec            5  Wednesday   Honda        Urban          Tuesday
# 1   Jan            3  Wednesday   Honda        Urban           Monday
# 2   Oct            5     Friday   Honda        Urban         Thursday
# 3   Jun            2   Saturday  Toyota        Rural           Friday
# 4   Jan            5     Monday   Honda        Urban          Tuesday
#
#   MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  AgeOfVehicle  \
# 0          Jan                   1  Female        Single  ...       3 years
# 1          Jan                   4    Male        Single  ...       6 years
# 2          Nov                   2    Male       Married  ...       7 years
# 3          Jul                   1    Male       Married  ...   more than 7
# 4          Feb                   2  Female        Single  ...       5 years
#
#   AgeOfPolicyHolder PoliceReportFiled WitnessPresent AgentType  \
# ...

# %%
df.isnull().sum()
df.dropna()
# Out:
#       Month  WeekOfMonth  DayOfWeek     Make AccidentArea DayOfWeekClaimed  \
# 0       Dec            5  Wednesday    Honda        Urban          Tuesday
# 1       Jan            3  Wednesday    Honda        Urban           Monday
# 2       Oct            5     Friday    Honda        Urban         Thursday
# 3       Jun            2   Saturday   Toyota        Rural           Friday
# 4       Jan            5     Monday    Honda        Urban          Tuesday
# ...     ...          ...        ...      ...          ...              ...
# 15415   Nov            4     Friday   Toyota        Urban          Tuesday
# 15416   Nov            5   Thursday  Pontiac        Urban           Friday
# 15417   Nov            5   Thursday   Toyota        Rural           Friday
# 15418   Dec            1     Monday   Toyota        Urban         Thursday
# 15419   Dec            2  Wednesday   Toyota        Urban         Thursday
#
#       MonthClaimed  WeekOfMonthClaimed     Sex MaritalStatus  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Month', 'WeekOfMonth', 'DayOfWeek', 'Make', 'AccidentArea',
#        'DayOfWeekClaimed', 'MonthClaimed', 'WeekOfMonthClaimed', 'Sex',
#        'MaritalStatus', 'Age', 'Fault', 'PolicyType', 'VehicleCategory',
#        'VehiclePrice', 'FraudFound_P', 'PolicyNumber', 'RepNumber',
#        'Deductible', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType',
#        'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'Year',
#        'BasePolicy'],
#       dtype='object')

# %%
#check datset nature
df['FraudFound_P'] = (df['FraudFound_P']>0).astype(int)
print(f"Not Fraud:{sum(df['FraudFound_P']==0)}")
print(f"Fraud:{sum(df['FraudFound_P']==1)}")
# Out:
# Not Fraud:14497
# Fraud:923

# %%
print("Data set is inbalanced")
# Out:
# Data set is inbalanced

# %%
X =df.drop('FraudFound_P',axis=1)
y=df['FraudFound_P']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
print(f"Shape of X_train before encoding: {X_train.shape}")
# Out:
# Shape of X_train before encoding: (12336, 32)

# %%
categorical_cols = X_train.select_dtypes(include='object').columns
print(f"Categorical columns to encode: {list(categorical_cols)}")

X_train_encoded = pd.get_dummies(X_train, columns=categorical_cols, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, columns=categorical_cols, drop_first=True)
# Out:
# Categorical columns to encode: ['Month', 'DayOfWeek', 'Make', 'AccidentArea', 'DayOfWeekClaimed', 'MonthClaimed', 'Sex', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'VehiclePrice', 'Days_Policy_Accident', 'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'PoliceReportFiled', 'WitnessPresent', 'AgentType', 'NumberOfSuppliments', 'AddressChange_Claim', 'NumberOfCars', 'BasePolicy']

# %%
print(f"Shape of X_train after encoding: {X_train_encoded.shape}")
print(f"Shape of X_test after encoding: {X_test_encoded.shape}")
# Out:
# Shape of X_train after encoding: (12336, 124)
# Shape of X_test after encoding: (3084, 116)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_train_encoded, y_train)

print("Before:", y_train.value_counts())
print("After:", y_res.value_counts())
# Out:
# Before: FraudFound_P
# 0    11598
# 1      738
# Name: count, dtype: int64
# After: FraudFound_P
# 0    11598
# 1    11598
# Name: count, dtype: int64

# %%
#stanndard scaler
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

X_res_scaled_smote=scaler.fit_transform(X_res)
X_test_scaled=scaler.transform(X_test_encoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       3 scaler=StandardScaler()
#       5 X_res_scaled_smote=scaler.fit_transform(X_res)
# ----> 6 X_test_scaled=scaler.transform(X_test_encoded)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %% [markdown]
# Random Forest

# %%
#model training
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(max_depth=5,
                               random_state=42)
#model fixing
rf_model.fit(x_res_scaled_smote, y_res_smote)
#model prediction
rf_pred=rf_model.predict(x_test_scaled)
# evaluation
from sklearn.metrics import accuracy_score
rf_acc=accuracy_score(y_test, rf_pred)
rf_acc

# %% [markdown]
# Decision Tree

# %%
#model training
from sklearn.tree import DecisionTreeClassifier
dt_model=DecisionTreeClassifier(max_depth=3,
                               random_state=42)
#model fixing
dt_model.fit(X_res_scaled_smote, y_res_smote)
#model prediction
dt_pred=rf_model.predict(X_test_scaled)
# evaluation
from sklearn.metrics import accuracy_score
dt_acc=accuracy_score(y_test, dt_pred)
dt_acc

# %% [markdown]
# SVM

# %%
#model training
from sklearn.svm import SVC
svm_model=SVC(kernel='rbf',
             C=1,
             random_state=45)
#model fixing
svm_model.fit(X_res_scaled_smote, y_res_smote)
#model prediction
svm_pred=rf_model.predict(X_test_scaled)
# evaluation
from sklearn.metrics import accuracy_score
svm_acc=accuracy_score(y_test, svm_pred)
svm_acc

# %%
model_accuracies={
    "DT":dt_acc,
    "RF":rf_acc,
    "SVM":svm_acc
}
model_accuracies

# %%
best_model_name=max(model_accuracies,
                    key=model_accuracies.get)
best_accuracy=model_accuracies[best_model_name]
print(f"\n Best Model: {best_model_name}with accuracy of {best_accuracy:4f}")
